# %%
# Creating new llama extract agent
import sys
from pathlib import Path

# Add parent directory (project root) to path
project_root = Path().resolve().parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from llama_cloud_services import LlamaExtract
from schemas import ExtractionSchema
from dotenv import load_dotenv

load_dotenv()

extractor = LlamaExtract()
agent = extractor.create_agent(name='advice_parser', data_schema=ExtractionSchema)
# result = agent.extract(filepath="financial_adviser_client_conversation.txt")

# %%
# Using parser service with existing agent to extract financial data from conversation

from services import ParserService
from infra.database import SessionLocal

db = SessionLocal()
# Out:
# /Users/oliver/Repos/AdviceTools/.venv/lib/python3.12/site-packages/pydantic/_internal/_config.py:383: UserWarning: Valid config keys have changed in V2:
# * 'allow_population_by_field_name' has been renamed to 'validate_by_name'
# * 'validate_all' has been renamed to 'validate_default'
#   warnings.warn(message, UserWarning)

# %%
parser = ParserService(
    user_id=1,
    filepath="financial_adviser_client_conversation.txt",
    db=db
)

financial_plan, cash_flows, portfolios = parser.extract_data()
# Out:
# Uploading files:   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 7
#       1 parser = ParserService(
#       2     user_id=1,
#       3     filepath="financial_adviser_client_conversation.txt",
#       4     db=db
#       5 )
# ----> 7 financial_plan, cash_flows, portfolios = parser.extract_data()
#
# File ~/Repos/AdviceTools/services/parser_service.py:25, in ParserService.extract_data(self)
#      22 def extract_data(self):
#      23     # TODO: Create agent if it doesn't already exist
#      24     agent = self.extractor.get_agent(name='advice_parser')
# ---> 25     data = agent.extract(self.filepath).data
#      26     financial_plan, cashflows, portfolios = self._build_data_objects(data)
#      28     return financial_plan, cashflows, portfolios
#
# File ~/Repos/AdviceTools/.venv/lib/python3.12/site-packages/llama_cloud_services/extract/extract.py:563, in ExtractionAgent.extract(self, files)
#     552 def extract(
#     553     self, files: Union[FileInput, List[FileInput]]
#     554 ) -> Union[ExtractRun, List[ExtractRun]]:
#     555     """Synchronously extract data from one or more files using this agent.
#     556
#     557     Args:
#    (...)    561         Union[ExtractRun, List[ExtractRun]]: The extraction results
#     562     """
# --> 563     return self._run_in_thread(self.aextract(files))
#
# File ~/Repos/AdviceTools/.venv/lib/python3.12/site-packages/llama_cloud_services/extract/extract.py:354, in ExtractionAgent._run_in_thread(self, coro)
#     352 def _run_in_thread(self, coro: Coroutine[Any, Any, T]) -> T:
#     353     """Run coroutine in a separate thread to avoid event loop issues"""
# --> 354     return run_in_thread(
#     355         coro,
#     356         self._thread_pool,
#     357         self.verify,  # type: ignore
#     358         self.httpx_timeout,  # type: ignore
#     359         self._client._client_wrapper,
#     360     )
#
# File ~/Repos/AdviceTools/.venv/lib/python3.12/site-packages/llama_cloud_services/extract/extract.py:262, in run_in_thread(coro, thread_pool, verify, httpx_timeout, client_wrapper)
#     259     except httpx.NetworkError as e:
#     260         raise ConnectionError(f"Network error: {str(e)}") from e
# --> 262 return thread_pool.submit(run_coro).result()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File ~/Repos/AdviceTools/.venv/lib/python3.12/site-packages/llama_cloud_services/extract/extract.py:256, in run_in_thread.<locals>.run_coro()
#     254 def run_coro() -> T:
#     255     try:
# --> 256         return asyncio.run(wrapped_coro())
#     257     except httpx.TimeoutException as e:
#     258         raise TimeoutError(f"Request timed out: {str(e)}") from e
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/asyncio/runners.py:194, in run(main, debug, loop_factory)
#     190     raise RuntimeError(
#     191         "asyncio.run() cannot be called from a running event loop")
#     193 with Runner(debug=debug, loop_factory=loop_factory) as runner:
# --> 194     return runner.run(main)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/asyncio/runners.py:118, in Runner.run(self, coro, context)
#     116 self._interrupt_count = 0
#     117 try:
# --> 118     return self._loop.run_until_complete(task)
#     119 except exceptions.CancelledError:
#     120     if self._interrupt_count > 0:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/asyncio/base_events.py:664, in BaseEventLoop.run_until_complete(self, future)
#     661 if not future.done():
#     662     raise RuntimeError('Event loop stopped before Future completed.')
# --> 664 return future.result()
#
# File ~/Repos/AdviceTools/.venv/lib/python3.12/site-packages/llama_cloud_services/extract/extract.py:249, in run_in_thread.<locals>.wrapped_coro()
#     247 try:
#     248     client_wrapper.httpx_client = client
# --> 249     return await coro
#     250 finally:
#     251     client_wrapper.httpx_client = original_client
#
# File ~/Repos/AdviceTools/.venv/lib/python3.12/site-packages/llama_cloud_services/extract/extract.py:539, in ExtractionAgent.aextract(self, files)
#     536     single_file = False
#     538 # Queue all files for extraction
# --> 539 jobs = await self.queue_extraction(files)
#     540 # Wait for all results concurrently
#     541 result_tasks = [self._wait_for_job_result(job.id) for job in jobs]
#
# File ~/Repos/AdviceTools/.venv/lib/python3.12/site-packages/llama_cloud_services/extract/extract.py:486, in ExtractionAgent.queue_extraction(self, files)
#     484 upload_tasks = [self._upload_file(file) for file in files]
#     485 with augment_async_errors():
# --> 486     uploaded_files: List[File] = await run_jobs(
#     487         upload_tasks,
#     488         workers=self.num_workers,
#     489         desc="Uploading files",
#     490         show_progress=self.show_progress,
#     491     )
#     493 job_tasks = [
#     494     self._client.llama_extract.run_job(
#     495         extraction_agent_id=self.id,
#    (...)    500     for file in uploaded_files
#     501 ]
#     502 with augment_async_errors():
#
# File ~/Repos/AdviceTools/.venv/lib/python3.12/site-packages/llama_index_instrumentation/dispatcher.py:386, in Dispatcher.span.<locals>.async_wrapper(func, instance, args, kwargs)
#     378 self.span_enter(
#     379     id_=id_,
#     380     bound_args=bound_args,
#    (...)    383     tags=tags,
#     384 )
#     385 try:
# --> 386     result = await func(*args, **kwargs)
#     387 except BaseException as e:
#     388     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~/Repos/AdviceTools/.venv/lib/python3.12/site-packages/llama_index/core/async_utils.py:167, in run_jobs(jobs, show_progress, workers, desc)
#     164 if show_progress:
#     165     from tqdm.asyncio import tqdm_asyncio
# --> 167     results = await tqdm_asyncio.gather(*pool_jobs, desc=desc)
#     168 else:
#     169     results = await asyncio.gather(*pool_jobs)
#
# File ~/Repos/AdviceTools/.venv/lib/python3.12/site-packages/tqdm/asyncio.py:79, in tqdm_asyncio.gather(cls, loop, timeout, total, *fs, **tqdm_kwargs)
#      76     return i, await f
#      78 ifs = [wrap_awaitable(i, f) for i, f in enumerate(fs)]
# ---> 79 res = [await f for f in cls.as_completed(ifs, loop=loop, timeout=timeout,
#      80                                          total=total, **tqdm_kwargs)]
#      81 return [i for _, i in sorted(res)]
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/asyncio/tasks.py:621, in as_completed.<locals>._wait_for_one()
#     618 if f is None:
#     619     # Dummy value from _on_timeout().
#     620     raise exceptions.TimeoutError
# --> 621 return f.result()
#
# File ~/Repos/AdviceTools/.venv/lib/python3.12/site-packages/tqdm/asyncio.py:76, in tqdm_asyncio.gather.<locals>.wrap_awaitable(i, f)
#      75 async def wrap_awaitable(i, f):
# ---> 76     return i, await f
#
# File ~/Repos/AdviceTools/.venv/lib/python3.12/site-packages/llama_index_instrumentation/dispatcher.py:386, in Dispatcher.span.<locals>.async_wrapper(func, instance, args, kwargs)
#     378 self.span_enter(
#     379     id_=id_,
#     380     bound_args=bound_args,
#    (...)    383     tags=tags,
#     384 )
#     385 try:
# --> 386     result = await func(*args, **kwargs)
#     387 except BaseException as e:
#     388     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~/Repos/AdviceTools/.venv/lib/python3.12/site-packages/llama_index/core/async_utils.py:160, in run_jobs.<locals>.worker(job)
#     157 @dispatcher.span
#     158 async def worker(job: Coroutine) -> Any:
#     159     async with semaphore:
# --> 160         return await job
#
# File ~/Repos/AdviceTools/.venv/lib/python3.12/site-packages/llama_cloud_services/extract/extract.py:430, in ExtractionAgent._upload_file(self, file_input)
#     424     warnings.warn(
#     425         "Use SourceText instead of bytes or file-like objects",
#     426         DeprecationWarning,
#     427     )
#     428     source_text = SourceText(file=file_input, filename=filename)
# --> 430 return await self.upload_file(source_text)
#
# File ~/Repos/AdviceTools/.venv/lib/python3.12/site-packages/llama_cloud_services/extract/extract.py:382, in ExtractionAgent.upload_file(self, file_input)
#     379     file_contents = BytesIO(file_input.file.read().encode("utf-8"))
#     380 elif isinstance(file_input.file, (str, Path)):
#     381     # Handle file paths
# --> 382     file_contents = open(file_input.file, "rb")
#     383 elif isinstance(file_input.file, bytes):
#     384     # Handle bytes
#     385     file_contents = BytesIO(file_input.file)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'financial_adviser_client_conversation.txt'

# %%
financial_plan
# Out:
# FinancialPlan(id=2, user_id=1, name='Andrea', description='Andrea', start_age=42, retirement_age=65, plan_end_age=100, plan_start_date=datetime.datetime(2025, 12, 2, 15, 57, 50, 220511), current_portfolio_value=120000.0, portfolio_target_value=0.0)

# %%
cash_flows
# Out:
# [CashFlow(id=1, plan_id=2, name='Salary', description='Salary', amount=7916.67, start_date=datetime.datetime(2025, 12, 31, 0, 0), end_date=datetime.datetime(2048, 12, 31, 0, 0)),
#  CashFlow(id=2, plan_id=2, name='Rental income', description='Rental income', amount=1000.0, start_date=datetime.datetime(2025, 12, 31, 0, 0), end_date=datetime.datetime(2083, 12, 31, 0, 0)),
#  CashFlow(id=3, plan_id=2, name='Monthly expenses', description='Monthly expenses', amount=-4500.0, start_date=datetime.datetime(2025, 12, 31, 0, 0), end_date=datetime.datetime(2083, 12, 31, 0, 0))]
